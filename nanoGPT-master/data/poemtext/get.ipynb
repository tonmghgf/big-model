# %%
import os
import requests
import tiktoken
import numpy as np
# Out:
# c:\Users\acer\.conda\envs\rxl\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
input_file_path = r'tang_poet.txt'
with open(input_file_path, 'r') as f:
    data = f.read()  # 前面必须有空格！

# %%
n = len(data)
train_data = data[:int(n*0.9)]
val_data = data[int(n*0.9):]

# %%
enc = tiktoken.get_encoding("gpt2")
train_ids = enc.encode_ordinary(train_data)
val_ids = enc.encode_ordinary(val_data)
print(f"train has {len(train_ids):,} tokens")
print(f"val has {len(val_ids):,} tokens")
# Out:
# train has 2,566,026 tokens
# val has 285,501 tokens

# %%
import numpy as np
import os

# 这里必须先有 train_ids 和 val_ids 的数据（你前面代码处理好的）
# train_ids = ...
# val_ids = ...

# 保存为 bin 文件（正确写法，不使用 __file__）
train_ids = np.array(train_ids, dtype=np.uint16)
val_ids = np.array(val_ids, dtype=np.uint16)

# 直接保存到当前文件夹
train_ids.tofile('train.bin')
val_ids.tofile('val.bin')
